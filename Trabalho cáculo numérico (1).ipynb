# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import sympy as sy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from sklearn.pipeline import make_pipeline
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange

# %% [markdown]
# # Importação do arquivo CSV e Resultado do total de linhas e colunas

# %%
data = pd.read_csv('Vehicle.csv', header=(0))
print("Número de linhas e colunas:",data.shape)
data.head(25)
# Out:
# Número de linhas e colunas: (846, 19)
#     Comp  Circ  DCirc  RadRa  PrAxisRa  MaxLRa  ScatRa  Elong  PrAxisRect  \
# 0     95    48     83    178        72      10     162     42          20
# 1     91    41     84    141        57       9     149     45          19
# 2    104    50    106    209        66      10     207     32          23
# 3     93    41     82    159        63       9     144     46          19
# 4     85    44     70    205       103      52     149     45          19
# 5    107    57    106    172        50       6     255     26          28
# 6     97    43     73    173        65       6     153     42          19
# 7     90    43     66    157        65       9     137     48          18
# 8     86    34     62    140        61       7     122     54          17
# 9     93    44     98    197        62      11     183     36          22
# 10    86    36     70    143        61       9     133     50          18
# ...

# %% [markdown]
# # Regressões Lineares

# %%
#Regressão linear da circularidade em relação a variação escalonada ao longo do eixo principal
 
data = data.to_numpy()
y = data[:,10]
x = data[:,2]
X = np.array(x).reshape(-1, 1)
y = np.array(y)
modelo = LinearRegression().fit(X, y)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(X, y)
plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# 47.37205158140284
# [1.7207402]

# %%
y_pred=modelo.predict(X)
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.7472431741708515

# %%
x= np.array(x)
y = np.array(y)
correlacao = np.corrcoef(x.astype(float), y.astype(float))
print(correlacao)
# Out:
# [[1.         0.86443228]
#  [0.86443228 1.        ]]

# %% [markdown]
# # Regressão Linear 2

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import sympy as sy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from sklearn.pipeline import make_pipeline
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange

# %%
#Regressão linear da variação escalonada ao longo do eixo principal e variação escalonada ao longo do eixo menor

data = pd.read_csv('Vehicle.csv', header=(0))
data = data.to_numpy()
a = data[:,10]
b = data[:,11]
A = np.array(a).reshape(-1, 1)
b = np.array(b)
modelo = LinearRegression().fit(A, b)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(A, b)
plt.plot(A, modelo.predict(A), color = 'red')
# Out:
# -568.4877433226125
# [5.3460438]

# %%
b_pred=modelo.predict(A)
R2 = r2_score(b, b_pred)
print('R2:', R2)
# Out:
# R2: 0.90228697370772

# %%
a= np.array(a)
b = np.array(b)
correlacao = np.corrcoef(a.astype(float), b.astype(float))
print(correlacao)
# Out:
# [[1.         0.94988787]
#  [0.94988787 1.        ]]

# %% [markdown]
# # Regressão linear 3

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import sympy as sy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from sklearn.pipeline import make_pipeline
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange

# %%
#Regressão linear da variação escalonada ao longo do eixo principal e variação escalonada ao longo do eixo menor

data = pd.read_csv('Vehicle.csv', header=(0))
data = data.to_numpy()
a1 = data[:,16]
b1 = data[:,17]
A1= np.array(a1).reshape(-1, 1)
b1 = np.array(b1)
modelo = LinearRegression().fit(A1, b1)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(A1, b1)
plt.plot(A1, modelo.predict(A1), color = 'red')
# Out:
# -8.229320534082689
# [1.07901803]

# %%
b1_pred=modelo.predict(A1)
R2 = r2_score(b1, b1_pred)
print('R2:', R2)
# Out:
# R2: 0.799410897372028

# %%
a1= np.array(a1)
b1 = np.array(b1)
correlacao = np.corrcoef(a1.astype(float), b1.astype(float))
print(correlacao)
# Out:
# [[1.         0.89409781]
#  [0.89409781 1.        ]]

# %% [markdown]
# # Regressão linear 4

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import sympy as sy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from sklearn.pipeline import make_pipeline
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange

# %%
#Regressão linear da variação escalonada ao longo do eixo principal e variação escalonada ao longo do eixo menor

data = pd.read_csv('Vehicle.csv', header=(0))
data = data.to_numpy()
a1 = data[:,8]
b1 = data[:,7]
A1= np.array(a1).reshape(-1, 1)
b1 = np.array(b1)
modelo = LinearRegression().fit(A1, b1)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(A1, b1)
plt.plot(A1, modelo.predict(A1), color = 'red')
# Out:
# 99.89151904892866
# [-2.86442457]

# %%
b1_pred=modelo.predict(A1)
R2 = r2_score(b1, b1_pred)
print('R2:', R2)
# Out:
# R2: 0.9034739074985845

# %%
a1= np.array(a1)
b1 = np.array(b1)
correlacao = np.corrcoef(a1.astype(float), b1.astype(float))
print(correlacao)
# Out:
# [[ 1.         -0.95051244]
#  [-0.95051244  1.        ]]

# %% [markdown]
# # Regressão linear 5

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import sympy as sy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from sklearn.pipeline import make_pipeline
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange

# %%
#Regressão linear da variação escalonada ao longo do eixo principal e variação escalonada ao longo do eixo menor

data = pd.read_csv('Vehicle.csv', header=(0))
data = data.to_numpy()
a1 = data[:,1]
b1 = data[:,9]
A1= np.array(a1).reshape(-1, 1)
b1 = np.array(b1)
modelo = LinearRegression().fit(A1, b1)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(A1, b1)
plt.plot(A1, modelo.predict(A1), color = 'red')
# Out:
# 46.0662686014534
# [2.27215073]

# %%
b1_pred=modelo.predict(A1)
R2 = r2_score(b1, b1_pred)
print('R2:', R2)
# Out:
# R2: 0.932722848887179

# %%
a1= np.array(a1)
b1 = np.array(b1)
correlacao = np.corrcoef(a1.astype(float), b1.astype(float))
print(correlacao)
# Out:
# [[1.         0.96577578]
#  [0.96577578 1.        ]]

# %% [markdown]
# # Regressão Linear múltipla com OlS

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import sympy as sy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from sklearn.pipeline import make_pipeline
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange
import statsmodels.api as sm

# %%
data = pd.read_csv('Vehicle.csv', header=(0))
print("Número de linhas e colunas:",data.shape)
data.head(25)
# Out:
# Número de linhas e colunas: (846, 19)
#     Comp  Circ  DCirc  RadRa  PrAxisRa  MaxLRa  ScatRa  Elong  PrAxisRect  \
# 0     95    48     83    178        72      10     162     42          20
# 1     91    41     84    141        57       9     149     45          19
# 2    104    50    106    209        66      10     207     32          23
# 3     93    41     82    159        63       9     144     46          19
# 4     85    44     70    205       103      52     149     45          19
# 5    107    57    106    172        50       6     255     26          28
# 6     97    43     73    173        65       6     153     42          19
# 7     90    43     66    157        65       9     137     48          18
# 8     86    34     62    140        61       7     122     54          17
# 9     93    44     98    197        62      11     183     36          22
# 10    86    36     70    143        61       9     133     50          18
# ...

# %%
X = data[['ScVarmaxis','ScVarMaxis','MaxLRect']]
y = data[['Circ']]
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
est.summary()
# Out:
# C:\Users\Vitor\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Circ   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     5534.
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):               0.00
# Time:                        14:36:45   Log-Likelihood:                -1457.3
# No. Observations:                 846   AIC:                             2923.
# Df Residuals:                     842   BIC:                             2942.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# # Regressão Linear Multipla com scikitlearnig

# %%
#y = data[:,3]
#x = data[:,0:2]
#X = np.array(x).reshape(-1, 1)
#y = np.array(y)

y = data.iloc[:,1]
x = data.iloc[:,9:12]
X = np.array(x).reshape(-1, 1)
y = np.array(y)

# %%
# modelo de regressão linear múltipla
modelo = LinearRegression().fit(x, y)

y_pred = modelo.predict(x)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
l = plt.plot(y_pred, y, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')
plt.ylabel("y", fontsize=15)
plt.xlabel("Prediction", fontsize=15)

# mostra os valores preditos e originais
xl = np.arange(min(y), 1.2*max(y),(max(y)-min(y))/10)

yl = xl
plt.plot(xl, yl, 'r--')
plt.show(True)

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.9517287941450917
